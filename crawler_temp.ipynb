# %%
import requests
from bs4 import BeautifulSoup

'''
type參數：1(出租) 2(出售)

kind參數：1(整層住家) 2(獨立套房) 3(分租套房) 4(雅房) 5(店面) 6(辦公) 7(廠房) 8(車位) 9(住宅) 10(套房)
    11(土地) 12(住辦) 13(餐飲食品) 14(服飾精品) 15(文化教育) 16(零售百貨) 17(交通運輸) 18(家居裝飾) 19(其他) 20(生活休閒)
    21(場地) 22(法拍屋) 23(攤位) 24(其他) 25(商業地產)
    
regionid參數：1(台北市) 2(基隆市) 3(新北市) 4(新竹市) 5(新竹縣) 6(桃園市) 7(苗栗縣) 8(台中市) 9(xx) 10(彰化縣)
    11(南投縣) 12(嘉義市) 13(嘉義縣) 14(雲林縣) 15(台南市) 16(xx) 17(高雄市) 18(xx) 19(屏東縣) 20(xx)
    21(宜蘭縣) 22(台東縣) 23(花蓮縣) 24(澎湖縣) 25(金門縣) 26(連江縣)
'''

# %%
my_headers={'user-agent':'crawler_test'}
#my_cookies=dict('urlJumpIp':'1')

para_region=1
para_type=1
para_kind=7

r=requests.get('https://business.591.com.tw/?type='+para_type+'&kind='+para_kind'&regionid='+para_region,headers=my_headers)

# %%
soup=BeautifulSoup(r.text,'html5lib')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head>
#
#     <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="zh-TW" http-equiv="content-language"/>
# <meta content="數字科技股份有限公司" name="author"/>
# <meta content="591.com.tw" name="copyright"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <title>【台中市廠房出租】-591房屋交易網</title>
# <meta content="台中市廠房出租,廠房出租,591,出租,591出租" name="keywords"/>
# <meta content="591廠房出租頻道,為您提供台中市最豐富的廠房資訊,還有店面,辦公,住辦,車位,土地出租資訊,讓您快速找到滿意的物件。找廠房就上591！" name="description"/>
# <meta content="index,follow" name="robots"/>
# <meta content="index,follow,archive" name="googlebot"/>
# <meta content="hEZ-1CusNSS7yOwwpax-fT1lpRNSdL8muaPV-Ek1eIc" name="google-site-verification"/>
# <!-- Open Graph data -->
# <meta content="【台中市廠房出租】-591房屋交易網" property="og:title"/>
# <meta content="company" property="og:type"/>
# <meta content="https://business.591.com.tw/?type=1&amp;kind=7" property="og:url"/>
# ...

# %%
'''
https://github.com/seekingtw/Crawler
https://github.com/neighborhood999/fiveN1-rent-scraper

'''
